# %%
import json
import pandas as pd
import numpy as np
import nltk
import pickle
from nltk import PunktSentenceTokenizer
import matplotlib.pyplot as plt
# nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/chamod/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))
stop_words.add('.')
stop_words.add(',')

tokenizer = PunktSentenceTokenizer()
def pos_tag(sentence):
    res_tokens = []
    tokens_temp = tokenizer.tokenize(sentence)
    tokens = []
    for t in tokens_temp :
        words = nltk.word_tokenize(t)
        tagged = nltk.pos_tag(words)
        tagged = [t for t in tagged if t[0] not in stop_words]
        tokens += tagged
    return tokens

def getSentences(file_name) :
    sentences = []
    with open(file_name) as f :
        reviews = json.load(f)['Reviews']['Review']
        for d in reviews:
            for s in d["sentences"]['sentence']:
                aspect_terms = []
                if "Opinions" in s :
                    opinions = s['Opinions']['Opinion']
                    if isinstance(opinions, list) :
                        for o in opinions :
                            aspect_terms.append(o['@target'])
                    else :
                        aspect_terms.append(opinions['@target'])
                        
                    pos_tagged = pos_tag(s['text'])
                    tagged = []
                    for t in pos_tagged:
                        if t[0] in aspect_terms:
                            tagged.append((t[0], t[1], 1))
                        else :
                            tagged.append((t[0], t[1], 0))
                    sentences.append(tagged)
    return sentences

train_sentences = getSentences('Data/ABSA-15_Restaurants_Train.json')

with open('train_sentences.pkl', 'wb') as f:
    pickle.dump(train_sentences, f)

with open('train_sentences.pkl', 'rb') as f:
    train_sentences = pickle.load(f)

print(train_sentences[8])
# Out:
# [(u'The', 'DT', 0), (u'duck', 'NN', 0), (u'confit', 'NN', 0), (u'always', 'RB', 0), (u'amazing', 'JJ', 0), (u'foie', 'NN', 0), (u'gras', 'NNS', 0), (u'terrine', 'VBP', 0), (u'figs', 'NNS', 0), (u'world', 'NN', 0)]

# %%
plt.style.use("ggplot")
plt.hist([len(s) for s in train_sentences], bins=50)
plt.show()

# %%
word_set = set()

for s in train_sentences:
    for t in s:
        word_set.add(t[0])

words = list(word_set)
words.append("ENDPAD")

n_words = len(words); n_words
# Out:
# 2559

# %%
max_len = 35
word2idx = {w: i+1 for i, w in enumerate(words)}

# word2idx
# words

# %%
from keras.preprocessing.sequence import pad_sequences
X = [[word2idx[w[0]] for w in s] for s in train_sentences]
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=0)

# %%
X[1]
# Out:
# array([ 995,    3, 1026, 1771, 1188,  294,  892, 1722,  294, 2273, 1706,
#        1816, 1023, 1438, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558,
#        2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558,
#        2558, 2558], dtype=int32)

# %%
y = [[w[2] for w in s] for s in train_sentences]

# %%
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=0)

# %%
y[1]
X.shape
# Out:
# (1120, 35)

# %%
from sklearn.model_selection import train_test_split
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.1, shuffle=False)

# X_tr = X_tr.reshape(X_tr.shape[0], 1, X_tr.shape[1])

# y_tr = y_tr.reshape(y_tr.shape[0], 1, y_tr.shape[1])

X_tr[0]
# Out:
# array([ 569,  493,  678,  202, 1090,  892,  633, 2558, 2558, 2558, 2558,
#        2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558,
#        2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558, 2558,
#        2558, 2558], dtype=int32)

# %%
from keras.models import Model, Input, Sequential
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Flatten
from keras.callbacks import EarlyStopping

earlyStopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')


model = Sequential()
model.add(Embedding(input_dim=n_words, output_dim=max_len, input_length=max_len, mask_zero=True))
model.add(Dropout(0.1))
model.add(Bidirectional(LSTM(units=128, return_sequences=True, recurrent_dropout=0.1)))
model.add(Bidirectional(LSTM(units=64, return_sequences=True, recurrent_dropout=0.1)))
model.add(Flatten())
model.add(Dense(activation='softmax', output_dim=max_len))

# model = Model(inputt, out)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X_tr, y_tr, batch_size=32, epochs=20, validation_split=0.1, verbose=1, callbacks=[earlyStopper])

hist = pd.DataFrame(history.history)
plt.figure(figsize=(12,12))
# plt.plot(hist["acc"] , label='acc')
# plt.plot(hist["val_acc"] , label='val_acc')

plt.plot(hist['loss'], label='loss')
plt.plot(hist['val_loss'], label='val_loss')
plt.legend()
plt.show()

# hist
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=35, activation="softmax")`
# Train on 907 samples, validate on 101 samples
# Epoch 1/20
# 907/907 [==============================] - 6s 7ms/step - loss: 0.0861 - acc: 0.9772 - val_loss: 0.0749 - val_acc: 0.9785
# Epoch 2/20
# 907/907 [==============================] - 3s 4ms/step - loss: 0.0785 - acc: 0.9772 - val_loss: 0.0729 - val_acc: 0.9785
# Epoch 3/20
# 907/907 [==============================] - 4s 4ms/step - loss: 0.0740 - acc: 0.9773 - val_loss: 0.0718 - val_acc: 0.9788
# Epoch 4/20
# 907/907 [==============================] - 3s 4ms/step - loss: 0.0690 - acc: 0.9792 - val_loss: 0.0746 - val_acc: 0.9785
# Epoch 5/20
# 907/907 [==============================] - 4s 4ms/step - loss: 0.0637 - acc: 0.9808 - val_loss: 0.0774 - val_acc: 0.9788
# Epoch 6/20
# 907/907 [==============================] - 3s 4ms/step - loss: 0.0595 - acc: 0.9816 - val_loss: 0.0791 - val_acc: 0.9777
# Epoch 7/20
# 907/907 [==============================] - 3s 4ms/step - loss: 0.0553 - acc: 0.9820 - val_loss: 0.0800 - val_acc: 0.9779
# Epoch 8/20
# 907/907 [==============================] - 3s 4ms/step - loss: 0.0534 - acc: 0.9830 - val_loss: 0.0867 - val_acc: 0.9774
# Epoch 00008: early stopping

# %%
i = 2
p = model.predict(np.array([X_te[i]]))
# p = np.argmax(p, axis=-1)

words_p = [words[w] for w in X_te[i]]


print(' '.join([x[0] for x in train_sentences[len(X_tr) + i]]))
print(train_sentences[len(X_tr) + i])

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)

plt.plot(words_p, p[0])
for xy in zip(words_p, p[0]):                                       
    ax.annotate('%s' % xy[0], xy=xy, textcoords='data')

plt.grid()
plt.show()

# p.max()
# X_te[i][10]
# print(words[X_te[i][p[0]]])

# print("{:15} ({:5})".format("Word", "True"))

# j = 0
# for w in X_tr[i]:
#     if j == p[0]:
#         print("{:15} {:5}").format(words[w], 1)
#     else :
#         print("{:15} {:5}").format(words[w], 0)
#     j += 1
# for w, pred in zip(X_te[i], p[0]):
#     print("{:15}: {}".format(words[w], tags[pred]))
# Out:
# Toons recently redone 's attractive space
# [(u'Toons', 'NNS', 1), (u'recently', 'RB', 0), (u'redone', 'NN', 0), (u"'s", 'VBZ', 0), (u'attractive', 'JJ', 0), (u'space', 'NN', 0)]
