# %%
import numpy as np
from keras.preprocessing import text, sequence
import json
import gensim
import pickle
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
max_features = 5000
maxlen = 50
embed_size = 300

# %%
def getSentences(file_name, hasLabels = True) :
    sentences = []
    aspects = []
    with open(file_name) as f :
        reviews = json.load(f)['Reviews']['Review']
        for d in reviews:
            sen = d["sentences"]['sentence']
            if isinstance(sen, list) :
                for s in sen:
                    sentences.append(s['text'])
                    if hasLabels:
                        aspect_terms = []
                        if "Opinions" in s :
                                opinions = s['Opinions']['Opinion']
                                if isinstance(opinions, list) :
                                    for o in opinions :
                                        aspect_terms.append([x.lower() for x in o['@target'].strip().split(" ")])
                                else :
                                    aspect_terms.append([x.lower() for x in opinions['@target'].strip().split(" ")])
                        aspects.append(aspect_terms)
            else :
                sentences.append(sen['text'])
                if hasLabels:
                        aspect_terms = []
                        if "Opinions" in sen :
                                opinions = sen['Opinions']['Opinion']
                                if isinstance(opinions, list) :
                                    for o in opinions :
                                        aspect_terms.append([x.lower() for x in o['@target'].strip().split(" ")])
                                else :
                                    aspect_terms.append([x.lower() for x in opinions['@target'].strip().split(" ")])
                        aspects.append(aspect_terms)
    return sentences, aspects


train_sentences, train_aspects = getSentences('Data/ABSA-15_Restaurants_Train.json')
test_sentences, test_aspects = getSentences('Data/ABSA15_Restaurants_Test.json')

# %%
# train_sentences

# %%
tokenizer = text.Tokenizer(num_words=max_features,filters='.!"#$%&()*+,-/:;<=>?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(train_sentences + test_sentences)

# %%
# EMBEDDING_FILE = 'GoogleNews-vectors-negative300.bin.gz'

# embeddings_index = gensim.models.KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)

# embeddings_index['dog'].shape

# %%
# word_index = tokenizer.word_index
# nb_words = max(max_features, len(word_index))
# embedding_matrix = np.zeros((nb_words, embed_size))
# without_embed = []
# n=0
# m = 0
# for word, i in word_index.items():
#     if i >= max_features: break
#     try:
#         embedding_vector = embeddings_index[word]
#         if embedding_vector is not None: 
#             embedding_matrix[i] = embedding_vector
#             m += 1
#     except:
#             n += 1
#             without_embed.append(word)
# #             print word 
            
# print "Words without embeddings %d" % n

# print "Words with embeddings %d" % m

# %%
# with open('embedding_matrix_300.pkl','wb') as f:
#     pickle.dump(embedding_matrix,f)

# %%
with open('embedding_matrix_300.pkl','rb') as f:
    embedding_matrix = pickle.load(f)

# %%
# embeddings_index['dog']

# %%
# trainX = tokenizer.texts_to_sequences(train_sentences)
# testX = tokenizer.texts_to_sequences(test_sentences)

# trainX = sequence.pad_sequences(trainX, maxlen=maxlen, padding="post")
# testX = sequence.pad_sequences(testX, maxlen=maxlen, padding="post")

# %%
# # plt.style.use("ggplot")
# plt.hist([len(s) for s in trainX], bins=50)
# plt.show()

# %%
def get_labels(X, aspects) :
    lenn = len(X)
    y = []
    for i in range(lenn):
        labels = []
        for j in X[i]:
            if j == 0 :
                labels.append(0)
            else:
                stop = False
                for w,k in tokenizer.word_index.items():
                    if k == j :
                        for a in aspects[i]:
                            if w in a :
                                labels.append(1)
                                stop = True
                                break
                        if stop : break
                    if stop : break
                if not stop : labels.append(0) 
        y.append(labels)
        print str(i) + '/' + str(lenn)
    return y


# trainY = get_labels(trainX, train_aspects)
# testY = get_labels(testX, test_aspects)

# %%
# with open('trainX.pkl', 'wb') as f:
#     pickle.dump(trainX, f)
# with open('trainY.pkl', 'wb') as f:
#     pickle.dump(trainY, f)
# with open('testX.pkl', 'wb') as f:
#     pickle.dump(testX, f)
# with open('testY.pkl', 'wb') as f:
#     pickle.dump(testY, f)

# %%
with open('trainX.pkl', 'rb') as f:
    trainX = pickle.load(f)
with open('trainY.pkl', 'rb') as f:
    trainY = np.array(pd.DataFrame(pickle.load(f)))
with open('testX.pkl', 'rb') as f:
    testX = pickle.load(f)
with open('testY.pkl', 'rb') as f:
    testY = np.array(pd.DataFrame(pickle.load(f)))

# %%
# k = 8 #8
# print train_sentences[k]
# print trainX[k]

# # for c in trainX[0]:
# #     tokenizer

# def get_words(seq):
#     words = []
#     for ind in seq:
#         if ind == 0 : break
#         for w,i in tokenizer.word_index.items():
#             if i == ind :
#                 words.append(w)
#                 break
#     return words

# print get_words(trainX[k])
# print train_aspects[k]
# print trainY[k]

# %%
from keras import backend as K

def recall(y_true, y_pred):
    """Recall metric.

    Only computes a batch-wise average of recall.

    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall


def precision(y_true, y_pred):
    """Precision metric.

    Only computes a batch-wise average of precision.

    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1(y_true, y_pred):
    prec = precision(y_true, y_pred)
    rec = recall(y_true, y_pred)
    return 2*((prec*rec)/(prec+rec+K.epsilon()))

# %%
from keras.models import Model, Input, Sequential
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Flatten
from keras.callbacks import EarlyStopping
from keras_contrib.layers import CRF

earlyStopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')


model = Sequential()
model.add(Embedding(input_dim=max_features, output_dim=embed_size, weights=[embedding_matrix], 
                    trainable = False, batch_input_shape=(None, maxlen)))
# model.add(Embedding(input_dim=max_features, output_dim=maxlen, input_length=maxlen))
model.add(Dropout(0.1))
model.add(LSTM(units=maxlen, return_sequences=True, recurrent_dropout=0.1))
model.add(Flatten())
# model.add(LSTM(units=maxlen, return_sequences=False, recurrent_dropout=0.1))
model.add(Dense(activation='sigmoid', output_dim=maxlen))


model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", f1, precision, recall])

history = model.fit(trainX, trainY, batch_size=32, epochs=50, validation_split=0.1, verbose=1, callbacks=[earlyStopper])

hist = pd.DataFrame(history.history)
plt.figure(figsize=(12,12))
plt.plot(hist['precision'], label='precision')
plt.plot(hist['val_precision'], label='val_precision')
plt.plot(hist['recall'], label='recall')
plt.plot(hist['val_recall'], label='val_recall')
plt.legend()
plt.show()

# hist

# from keras.utils import plot_model
# plot_model(model, to_file='model.png')

# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot

# SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=50, activation="sigmoid")`
# Train on 1183 samples, validate on 132 samples
# Epoch 1/50
# 1183/1183 [==============================] - 3s 3ms/step - loss: 0.2564 - acc: 0.9491 - f1: 0.0073 - precision: 0.0048 - recall: 0.0304 - val_loss: 0.1310 - val_acc: 0.9700 - val_f1: 0.0000e+00 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.1005 - acc: 0.9740 - f1: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1196 - val_acc: 0.9700 - val_f1: 0.0000e+00 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0900 - acc: 0.9740 - f1: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.0977 - val_acc: 0.9702 - val_f1: 0.0108 - val_precision: 0.2424 - val_recall: 0.0055
# Epoch 4/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0803 - acc: 0.9746 - f1: 0.0584 - precision: 0.5064 - recall: 0.0318 - val_loss: 0.0910 - val_acc: 0.9705 - val_f1: 0.0493 - val_precision: 0.4848 - val_recall: 0.0261
# Epoch 5/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0737 - acc: 0.9758 - f1: 0.1597 - precision: 0.7712 - recall: 0.0922 - val_loss: 0.0830 - val_acc: 0.9717 - val_f1: 0.1882 - val_precision: 0.6545 - val_recall: 0.1106
# Epoch 6/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0685 - acc: 0.9764 - f1: 0.2370 - precision: 0.7297 - recall: 0.1465 - val_loss: 0.0779 - val_acc: 0.9745 - val_f1: 0.3529 - val_precision: 0.7114 - val_recall: 0.2362
# Epoch 7/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0617 - acc: 0.9780 - f1: 0.3269 - precision: 0.7946 - recall: 0.2117 - val_loss: 0.0751 - val_acc: 0.9744 - val_f1: 0.3083 - val_precision: 0.7734 - val_recall: 0.1946
# Epoch 8/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0556 - acc: 0.9798 - f1: 0.4081 - precision: 0.8327 - recall: 0.2766 - val_loss: 0.0726 - val_acc: 0.9753 - val_f1: 0.4247 - val_precision: 0.6549 - val_recall: 0.3189
# Epoch 9/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0503 - acc: 0.9820 - f1: 0.5134 - precision: 0.8563 - recall: 0.3736 - val_loss: 0.0703 - val_acc: 0.9768 - val_f1: 0.4446 - val_precision: 0.7134 - val_recall: 0.3295
# Epoch 10/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0456 - acc: 0.9839 - f1: 0.5896 - precision: 0.8586 - recall: 0.4580 - val_loss: 0.0686 - val_acc: 0.9771 - val_f1: 0.4541 - val_precision: 0.7813 - val_recall: 0.3219
# Epoch 11/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0418 - acc: 0.9848 - f1: 0.6169 - precision: 0.8526 - recall: 0.4917 - val_loss: 0.0690 - val_acc: 0.9776 - val_f1: 0.4652 - val_precision: 0.8027 - val_recall: 0.3312
# Epoch 12/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0385 - acc: 0.9858 - f1: 0.6593 - precision: 0.8535 - recall: 0.5463 - val_loss: 0.0654 - val_acc: 0.9788 - val_f1: 0.5417 - val_precision: 0.7529 - val_recall: 0.4290
# Epoch 13/50
# 1183/1183 [==============================] - 2s 2ms/step - loss: 0.0351 - acc: 0.9876 - f1: 0.7167 - precision: 0.8754 - recall: 0.6138 - val_loss: 0.0641 - val_acc: 0.9798 - val_f1: 0.5710 - val_precision: 0.7599 - val_recall: 0.4686
# Epoch 14/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0324 - acc: 0.9884 - f1: 0.7354 - precision: 0.8741 - recall: 0.6486 - val_loss: 0.0645 - val_acc: 0.9797 - val_f1: 0.5542 - val_precision: 0.7867 - val_recall: 0.4418
# Epoch 15/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0302 - acc: 0.9894 - f1: 0.7584 - precision: 0.8829 - recall: 0.6725 - val_loss: 0.0633 - val_acc: 0.9798 - val_f1: 0.5571 - val_precision: 0.8029 - val_recall: 0.4343
# Epoch 16/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0286 - acc: 0.9900 - f1: 0.7845 - precision: 0.8827 - recall: 0.7127 - val_loss: 0.0633 - val_acc: 0.9806 - val_f1: 0.5797 - val_precision: 0.8070 - val_recall: 0.4603
# Epoch 17/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0264 - acc: 0.9908 - f1: 0.7971 - precision: 0.9045 - recall: 0.7211 - val_loss: 0.0624 - val_acc: 0.9794 - val_f1: 0.5898 - val_precision: 0.7155 - val_recall: 0.5069
# Epoch 18/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0248 - acc: 0.9914 - f1: 0.8172 - precision: 0.9054 - recall: 0.7488 - val_loss: 0.0623 - val_acc: 0.9802 - val_f1: 0.6180 - val_precision: 0.7198 - val_recall: 0.5445
# Epoch 19/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0237 - acc: 0.9917 - f1: 0.8230 - precision: 0.8998 - recall: 0.7636 - val_loss: 0.0621 - val_acc: 0.9803 - val_f1: 0.6176 - val_precision: 0.7382 - val_recall: 0.5390
# Epoch 20/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0225 - acc: 0.9922 - f1: 0.8358 - precision: 0.9024 - recall: 0.7872 - val_loss: 0.0624 - val_acc: 0.9820 - val_f1: 0.6253 - val_precision: 0.8004 - val_recall: 0.5226
# Epoch 21/50
# 1183/1183 [==============================] - 2s 1ms/step - loss: 0.0209 - acc: 0.9929 - f1: 0.8488 - precision: 0.9158 - recall: 0.7970 - val_loss: 0.0653 - val_acc: 0.9809 - val_f1: 0.5872 - val_precision: 0.8111 - val_recall: 0.4670
# Epoch 22/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0200 - acc: 0.9933 - f1: 0.8595 - precision: 0.9216 - recall: 0.8114 - val_loss: 0.0635 - val_acc: 0.9821 - val_f1: 0.6368 - val_precision: 0.8110 - val_recall: 0.5341
# Epoch 23/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0191 - acc: 0.9938 - f1: 0.8716 - precision: 0.9264 - recall: 0.8271 - val_loss: 0.0638 - val_acc: 0.9808 - val_f1: 0.6287 - val_precision: 0.7298 - val_recall: 0.5614
# Epoch 24/50
# 1183/1183 [==============================] - 1s 1ms/step - loss: 0.0183 - acc: 0.9938 - f1: 0.8707 - precision: 0.9231 - recall: 0.8276 - val_loss: 0.0634 - val_acc: 0.9812 - val_f1: 0.6521 - val_precision: 0.7343 - val_recall: 0.5938
# Epoch 00024: early stopping

# %%
# plt.plot(hist["acc"] , label='acc')
# plt.plot(hist["val_acc"] , label='val_acc')

plt.plot(hist['loss'], label='loss')
plt.plot(hist['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

threshold = 0.5

testY_pred = model.predict(testX)
# pred_y_te = np.round(pred_y_te)
testY_pred = np.array([ [0 if e < threshold else 1 for e in p] for p in testY_pred ])

testY_pred[6]

print('Precision : ' + str(precision_score(testY, testY_pred, average='micro')))
print('Recall : ' + str(recall_score(testY, testY_pred, average='micro')))
print('F1-score : ' + str(f1_score(testY, testY_pred, average='micro')))
# Out:
# Precision : 0.6886930983847284
# Recall : 0.5790123456790124
# F1-score : 0.6291079812206573

# %%
def processSentence(text):
    temp = tokenizer.texts_to_sequences([text])
    temp = sequence.pad_sequences(temp, maxlen=maxlen, padding="post")
    return temp[0]

def get_words(seq):
    words = []
    for ind in seq:
        if ind == 0 : 
            words.append('__')
        for w,i in tokenizer.word_index.items():
            if i == ind :
                words.append(w)
                break
    return words

# %%
# ex = 'The food is very average...the crispy chicken is a bit too sweet, every thing they serve is too sweet here.'
i = 99 #49 55 59  interesting - 89
ex = test_sentences[i]
X_ex = processSentence(ex)

print("sentence : " + ex)
print("aspects : " + str(test_aspects[i]))
p = model.predict(np.array([X_ex]))

# i = 45  #45 54 5 65 110 32  # 111 out
# p = model.predict(np.array([X_te[i]]))
# arg_p = np.argmax(p, axis=-1)
# print(arg_p)

words_p = get_words(X_ex)


# print(train_sentences[len(X_tr) + i])
# print(long_sentences[len(X_tr) + i])


fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.set_ylim([0,1])

plt.plot(words_p, p[0])
for xy in zip(words_p, p[0]):                                       
    ax.annotate('%s' % xy[0], xy=xy, textcoords='data')

plt.grid()
plt.show()
# Out:
# sentence : Favorite Sushi in NYC
# aspects : [[u'sushi']]
